# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 5, 50)
print(x)
y = 1.2*x + 0.8

#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

#Add Noise
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
print(x.shape)

#在最後一個維度增加維度
X = x.reshape(-1,1)
X.shape
regr.fit(X,y)
Y = regr.predict(X)
print(Y)
#了解你的訓練參數
regr.get_params()

plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)

#Y=WX+b
#係數表示每個自變數對應變數的影響程度，也就是特徵變量在預測結果中的權重
W=regr.coef_#斜率
b=regr.intercept_ #截距

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [-0.08823173  0.57301203  0.39626743  0.72078187  1.55217494  1.57851299
#   2.02405582  0.22321359  1.59563516  2.23256713  3.18772041  2.2386459
#   2.28566338  2.55900479  3.84029496  2.03598174  2.22118887  4.41789476
#   3.83300906  2.86894193  2.56702478  3.14172186  3.68832263  3.84134195
#   3.9287857   3.09359182  4.11187776  3.1010939   4.8796927   3.4406987
#   3.8456202   4.81911658  3.89789507  3.99658828  5.60078293  4.65884111
#   4.36459316  5.46203059  5.35994504  5.39065979  5.49627167  6.16430336
#   6.95651755  6.46302756  6.37684954  6.70114854  5.76753409  5.44445297
#   6.82551684  7.23368714]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)

#在最後一個維度增加維度
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.72191211 0.84503069 0.96814927 1.09126785 1.21438644 1.33750502
#  1.4606236  1.58374218 1.70686077 1.82997935 1.95309793 2.07621651
#  2.1993351  2.32245368 2.44557226 2.56869084 2.69180943 2.81492801
#  2.93804659 3.06116517 3.18428376 3.30740234 3.43052092 3.5536395
#  3.67675809 3.79987667 3.92299525 4.04611383 4.16923242 4.292351
#  4.41546958 4.53858816 4.66170675 4.78482533 4.90794391 5.03106249
#  5.15418108 5.27729966 5.40041824 5.52353682 5.64665541 5.76977399
#  5.89289257 6.01601115 6.13912974 6.26224832 6.3853669  6.50848548
#  6.63160407 6.75472265]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.4180729454974066

# %%
#Y=WX+b
#係數表示每個自變數對應變數的影響程度，也就是特徵變量在預測結果中的權重
W=regr.coef_#斜率
W
# Out:
# array([1.20656211])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.8000000000000016

# %%
Y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#可以將新的x資料帶入算出結果
W*3+b
# Out:
# array([4.4])

# %%
y
# Out:
# array([ 0.27525339,  1.33994008,  0.91197999, -0.20320858,  1.89085355,
#         0.60847933,  1.48341042,  0.93030304,  1.35044448,  2.53660118,
#         3.19097507,  1.59325492,  3.29520382,  2.39603642,  2.42674534,
#         3.32204164,  2.85852214,  2.90697684,  2.52972766,  3.11008526,
#         2.90785658,  3.85680041,  3.44705739,  3.42994352,  2.59456672,
#         3.79364206,  4.66116825,  3.79851919,  4.45159162,  4.30879935,
#         4.91409624,  4.70701615,  6.28523753,  4.07812527,  5.17605873,
#         4.62142594,  4.77138525,  4.78797527,  6.15181021,  4.81071081,
#         5.84798456,  5.19384327,  6.18938522,  5.53159052,  6.32867975,
#         5.78822922,  7.0023755 ,  7.53394173,  6.22492988,  5.53340938])
